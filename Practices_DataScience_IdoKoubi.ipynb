# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import matplotlib.gridspec as gridspec
import seaborn as sns
import os
import socket
from glob import glob
# %matplotlib notebook
socket.gethostname()
# Out:
# 'DESKTOP-G3TJ4UR'

# %%
# %qtconsole

# %%
df = pd.read_csv('cost_of_living_breakdown_2020 (1).csv')

# %%
df
# Out:
#      Unnamed: 0  Rank                      City  Meal, Inexpensive Restaurant  \
# 0             0   NaN  Saint Petersburg, Russia                          7.01
# 1             1   NaN            Samara, Russia                          6.91
# 2             2   NaN          Algiers, Algeria                          3.12
# 3             3   NaN          Istanbul, Turkey                          4.42
# 4             4   NaN      Porto Alegre, Brazil                          3.47
# ..          ...   ...                       ...                           ...
# 148         165   NaN      Melbourne, Australia                         11.81
# 149         166   NaN          Perth, Australia                         13.12
# 150         167   NaN         Sydney, Australia                         12.11
# 151         169   NaN         Alexandria, Egypt                          3.17
# 152         170   NaN            Quito, Ecuador                          3.25
#
# ...

# %%
df.head(2)
# Out:
#    Unnamed: 0  Rank                      City  Meal, Inexpensive Restaurant  \
# 0           0   NaN  Saint Petersburg, Russia                          7.01
# 1           1   NaN            Samara, Russia                          6.91
#
#    Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                              28.03
# 1                                              24.17
#
#    McMeal at McDonalds (or Equivalent Combo Meal)  \
# 0                                            4.20
# 1                                            4.14
#
#    Domestic Beer (0.5 liter draught)  Imported Beer (0.33 liter bottle)  \
# 0                               2.10                               2.17
# 1                               0.93                               1.93
#
#    Coke/Pepsi (0.33 liter bottle)  Water (0.33 liter bottle)  ...  \
# 0                            0.74                       0.53  ...
# ...

# %%
df[2:5]
# Out:
#    Unnamed: 0  Rank                  City  Meal, Inexpensive Restaurant  \
# 2           2   NaN      Algiers, Algeria                          3.12
# 3           3   NaN      Istanbul, Turkey                          4.42
# 4           4   NaN  Porto Alegre, Brazil                          3.47
#
#    Meal for 2 People, Mid-range Restaurant, Three-course  \
# 2                                              15.58
# 3                                              17.66
# 4                                              17.37
#
#    McMeal at McDonalds (or Equivalent Combo Meal)  \
# 2                                            3.90
# 3                                            3.68
# 4                                            4.34
#
#    Domestic Beer (0.5 liter draught)  Imported Beer (0.33 liter bottle)  \
# 2                               1.75                               1.95
# 3                               2.65                               2.94
# ...

# %%
# Sometimes we want to see the index of a DF (or of a Series) so we use the .index property
df.index
# It says that it starts with 0 and steps by 1 to 1052 (not including). 
# In this case the index values are the integral numbers: 0,1,2,...,1051. This is not always be the case.

# %%
df.dtypes
# Out:
# Unnamed: 0                                                                      int64
# Rank                                                                          float64
# City                                                                           object
# Meal, Inexpensive Restaurant                                                  float64
# Meal for 2 People, Mid-range Restaurant, Three-course                         float64
# McMeal at McDonalds (or Equivalent Combo Meal)                                float64
# Domestic Beer (0.5 liter draught)                                             float64
# Imported Beer (0.33 liter bottle)                                             float64
# Coke/Pepsi (0.33 liter bottle)                                                float64
# Water (0.33 liter bottle)                                                     float64
# Milk (regular), (1 liter)                                                     float64
# ...

# %%
df.select_dtypes(include='number').head()

# %%
df.select_dtypes(include='object').head(6)

# %%
df.select_dtypes(include=['number','object','category']).head(6)

# %%
df.select_dtypes(exclude='number').head(6)

# %%
pd.read_csv('cost_of_living_breakdown_2020 (1).csv')
# Out:
#      Unnamed: 0  Rank                      City  Meal, Inexpensive Restaurant  \
# 0             0   NaN  Saint Petersburg, Russia                          7.01
# 1             1   NaN            Samara, Russia                          6.91
# 2             2   NaN          Algiers, Algeria                          3.12
# 3             3   NaN          Istanbul, Turkey                          4.42
# 4             4   NaN      Porto Alegre, Brazil                          3.47
# ..          ...   ...                       ...                           ...
# 148         165   NaN      Melbourne, Australia                         11.81
# 149         166   NaN          Perth, Australia                         13.12
# 150         167   NaN         Sydney, Australia                         12.11
# 151         169   NaN         Alexandria, Egypt                          3.17
# 152         170   NaN            Quito, Ecuador                          3.25
#
# ...

# %%
df1= pd.read_csv('cost_of_living_numbeo_2020 (1).csv')

# %%
from glob import glob

# %%
stock_files = sorted(glob('cost_of_living*.csv'))
stock_files

# %%
pd.concat((pd.read_csv(file) for file in stock_files),axis='columns').head(10)

# %%
pd.concat((pd.read_csv(file) for file in stock_files))

# %%
df3.dtypes

# %%
df1.dtypes

# %%
df.head()
df.City.unique()

# %%
OECD_Numbers = df1.copy()

# %%
OECD_Numbers= OECD_Numbers[(OECD_Numbers.City=='Moscow,Russia')|
   (OECD_Numbers.City=='Lisbon, Portugal')|
   (OECD_Numbers.City=='Brussels, Belgium')|
   (OECD_Numbers.City=='Sydney, Australia')|
   (OECD_Numbers.City=='Paris, France')|
   (OECD_Numbers.City=='Zurich, Switzerland')|
   (OECD_Numbers.City=='Singapore, Singapore')|
   (OECD_Numbers.City=='Bogota, Colombia')|                  
   (OECD_Numbers.City=='Rome, Italy')|
   (OECD_Numbers.City=='Prague, Czech Republic')|
   (OECD_Numbers.City=='Madrid, Spain')|
   (OECD_Numbers.City=='Vienna, Austria')|
   (OECD_Numbers.City=='Toronto, Canada')|
   (OECD_Numbers.City=='Seoul, South Korea')|
   (OECD_Numbers.City=='Helsinki, Finland')|
   (OECD_Numbers.City=='Amsterdam, Netherlands')|
   (OECD_Numbers.City=='Stockholm,Sweden')|
   (OECD_Numbers.City=='Oslo,Norway')|
   (OECD_Numbers.City=='Houston,TX,United States')|
   (OECD_Numbers.City=='New York,NY,United States')|
   (OECD_Numbers.City=='Miami,FL,United States')|
   (OECD_Numbers.City=='Los Angeles, CA, United States')|
   (OECD_Numbers.City=='Saint Petersburg, Russia')|
   (OECD_Numbers.City=='Mexico City, Mexico')|
   (OECD_Numbers.City=='Budapest,Hungary')|
   (OECD_Numbers.City=='Tel Aviv-Yafo, Israel')|
   (OECD_Numbers.City=='Copenhagen,Denmark')|
   (OECD_Numbers.City=='Dublin,Ireland')|
   (OECD_Numbers.City=='Tokyo, Japan')|
   (OECD_Numbers.City=='Auckland,New Zealand')|
   (OECD_Numbers.City=='Istanbul,Turkey')|
   (OECD_Numbers.City=='Santiago, Chile')|
   (OECD_Numbers.City=='Athens,Greece')|
   (OECD_Numbers.City=='London, United Kingdom')|
   (OECD_Numbers.City=='Taipei, Taiwan').head()]

# %%
OECD_Numbers['City']= OECD_Numbers['City'].replace({'Taipei, Taiwan':'Taipei','London, United Kingdom':'London', 'Athens, Greece':'Athens','Santiago, Chile':'Santiago','Istanbul, Turkey':'Istanbul','Auckland, New Zealand':'Auckland','Tokyo, Japan':'Tokyo','Dublin, Ireland':'Dublin','Copenhagen, Denmark':'Copenhagen','Tel Aviv-Yafo, Israel':'Tel Aviv','Budapest, Hungary':'Budapest','Mexico City, Mexico':'Mexico City','Saint Petersburg, Russia':'St Peterburg','Los Angeles, CA, United States':'Los Angeles','Miami, Fl, United States':'Miami','New York, NY, United States':'New York','Houston, TX, United States':'Houston','Oslo, Norway':'Oslo','Stockholm, Sweden':'Stockholm','Amsterdam, Netherlands':'Amsterdam','Helsinki, Finland':'Helsinki','Stockholm, Sweden':'Stockholm','Amsterdam, Netherlands':'Amsterdam','Helsinki, Finland':'Helsinki','Seoul, South Korea':'Seoul','Toronto, Canada':'Toronto','Vienna, Austria':'Vienna','Madrid, Spain':'Madrid','Prague, Czech Republic':'Prague','Rome, Italy':'Rome','Bogota, Colombia':'Bogota','Singapore, Singapore':'Singapore','Zurich, Switzerland':'Zurich','Paris, France':'Paris','Sydney, Australia':'Sydney','Brussels, Belgium':'Brussels','Lisbon, Portugal':'Lisbon','Moscown, Russia':'Moscow'})

# %%
#Filtering and droping Columns for OECD_Numbers DataFrame
OECD_Numbers =OECD_Numbers[['City','Groceries Index','Restaurant Price Index','Local Purchasing Power Index']]

# %%
OECD_Numbers.sort_values(by=['Local Purchasing Power Index','City'],ascending=False)
# Out:
#              City  Groceries Index  Restaurant Price Index  \
# 0          Zurich           127.96                  124.73
# 49    Los Angeles            71.23                   79.98
# 36         Sydney            71.21                   69.36
# 91       Brussels            60.66                   81.36
# 89       Helsinki            59.99                   82.03
# 17          Tokyo            83.42                   56.70
# 28      Singapore            66.75                   58.99
# 37      Amsterdam            59.03                   81.90
# 165        Vienna            56.51                   63.33
# 27         London            57.31                   89.04
# 41        Toronto            73.92                   76.31
# 22          Seoul           103.69                   45.88
# 19       Tel Aviv            73.01                   93.75
# 205        Madrid            45.53                   60.23
# 23          Paris            78.98                   81.35
# ...

# %%
OECD_Numbers.sort_values(by=['Local Purchasing Power Index'],ascending=True)
# Out:
#              City  Groceries Index  Restaurant Price Index  \
# 378        Bogota            26.13                   25.00
# 316   Mexico City            33.75                   33.11
# 259      Santiago            37.86                   44.94
# 283  St Peterburg            32.91                   40.60
# 226        Lisbon            39.26                   46.72
# 113          Rome            57.03                   74.45
# 243        Prague            39.59                   39.14
# 23          Paris            78.98                   81.35
# 205        Madrid            45.53                   60.23
# 19       Tel Aviv            73.01                   93.75
# 22          Seoul           103.69                   45.88
# 41        Toronto            73.92                   76.31
# 27         London            57.31                   89.04
# 165        Vienna            56.51                   63.33
# 37      Amsterdam            59.03                   81.90
# ...

# %%
OECD_Numbers.sort_values(by=['Groceries Index'],ascending=False)
# Out:
#              City  Groceries Index  Restaurant Price Index  \
# 0          Zurich           127.96                  124.73
# 22          Seoul           103.69                   45.88
# 17          Tokyo            83.42                   56.70
# 23          Paris            78.98                   81.35
# 41        Toronto            73.92                   76.31
# 19       Tel Aviv            73.01                   93.75
# 49    Los Angeles            71.23                   79.98
# 36         Sydney            71.21                   69.36
# 28      Singapore            66.75                   58.99
# 91       Brussels            60.66                   81.36
# 89       Helsinki            59.99                   82.03
# 37      Amsterdam            59.03                   81.90
# 27         London            57.31                   89.04
# 113          Rome            57.03                   74.45
# 165        Vienna            56.51                   63.33
# ...

# %%
OECD_Numbers.sort_values(by=['Restaurant Price Index'],ascending=True)
# Out:
#              City  Groceries Index  Restaurant Price Index  \
# 378        Bogota            26.13                   25.00
# 316   Mexico City            33.75                   33.11
# 243        Prague            39.59                   39.14
# 283  St Peterburg            32.91                   40.60
# 259      Santiago            37.86                   44.94
# 22          Seoul           103.69                   45.88
# 226        Lisbon            39.26                   46.72
# 17          Tokyo            83.42                   56.70
# 28      Singapore            66.75                   58.99
# 205        Madrid            45.53                   60.23
# 165        Vienna            56.51                   63.33
# 36         Sydney            71.21                   69.36
# 113          Rome            57.03                   74.45
# 41        Toronto            73.92                   76.31
# 49    Los Angeles            71.23                   79.98
# ...

# %%
OECD_Numbers.sort_values(by=['Restaurant Price Index'],ascending=False)
# Out:
#              City  Groceries Index  Restaurant Price Index  \
# 0          Zurich           127.96                  124.73
# 19       Tel Aviv            73.01                   93.75
# 27         London            57.31                   89.04
# 89       Helsinki            59.99                   82.03
# 37      Amsterdam            59.03                   81.90
# 91       Brussels            60.66                   81.36
# 23          Paris            78.98                   81.35
# 49    Los Angeles            71.23                   79.98
# 41        Toronto            73.92                   76.31
# 113          Rome            57.03                   74.45
# 36         Sydney            71.21                   69.36
# 165        Vienna            56.51                   63.33
# 205        Madrid            45.53                   60.23
# 28      Singapore            66.75                   58.99
# 17          Tokyo            83.42                   56.70
# ...

# %%
OECD_Numbers.to_csv("C:\\Users\\idoch\\OneDrive - Bar-Ilan University\\Documents\\Python Scripts\OECD_Numbers.csv")

# %%
OECD = df.copy()

# %%
#Filtering rows for a new Group within DF
OECD= OECD[(OECD.City=='Istanbul, Turkey')|
   (OECD.City=='Mexico City, Mexico')|
   (OECD.City=='Bogota, Colombia')|
   (OECD.City=='Santiago, Chile')|
   (OECD.City=='Brussels, Belgium')|
   (OECD.City=='New York, NY, United States')|
   (OECD.City=='Miami,CA,United States')|
   (OECD.City=='Los Angeles, CA, United States')|
   (OECD.City=='Amsterdam, Netherlands')|
   (OECD.City=='Stockholm, Sweden')|
   (OECD.City=='Helsinki, Finland')|
   (OECD.City=='Copenhagen, Denmark')|
   (OECD.City=='Athens, Greece')|
   (OECD.City=='Belgrade, Serbia')|
   (OECD.City=='Bucharest, Romania')|
   (OECD.City=='Dublin, Ireland')|
   (OECD.City=='Zurich, Switzerland')|
   (OECD.City=='Sofia, Bulgaria')|
   (OECD.City=='Vienna, Austria')|
   (OECD.City=='Johannesburg, South Africa')|
   (OECD.City=='Tel Aviv-Yafo, Israel')|
   (OECD.City=='Tokyo, Japan')|
   (OECD.City=='Seoul, South Korea')|
   (OECD.City=='Taipei, Taiwan')|
   (OECD.City=='Hong Kong, Hong Kong')|
   (OECD.City=='Singapore, Singapore')|
   (OECD.City=='London, United Kingdom')|
   (OECD.City=='Manchester, United Kingdom')|
   (OECD.City=='Paris, France')|
   (OECD.City=='Berlin, Germany')|
   (OECD.City=='Moscow, Russia')|
   (OECD.City=='Saint Peterburg, Russia')|
   (OECD.City=='Rome, Italy')|
   (OECD.City=='Madrid, Spain')|
   (OECD.City=='Lisbon, Portugal')|
   (OECD.City=='Warsaw, Poland')|
   (OECD.City=='Budapest, Hungary')|
   (OECD.City=='Oslo, Norway').head()]

# %%
#Creating New Column
OECD['new_column'] = "Salaries_for_Apartment"

# %%
#Creating New Column
OECD['new_column1'] = "Salaries_for_Toyota"

# %%
# Calculating how much salaries are needed to buy 100 square meter Apartment outside the city center.
#This is an important Factor for analysing Cost of living
OECD['new_column']=(100*df['Price per Square Meter to Buy Apartment Outside of Centre'])/df['Average Monthly Net Salary (After Tax)']

# %%
OECD['new_column1'] = df['Toyota Corolla Sedan 1.6l 97kW Comfort (Or Equivalent New Car)']/df['Average Monthly Net Salary (After Tax)']

# %%
#Filtering Columns for OECD DataFrame
OECD =OECD[['City','new_column','new_column1','Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment','Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate']]

# %%
OECD.rename(columns={'new_column':'Salaries_to_buy_Apartment'},inplace=True)

# %%
OECD.rename(columns={'new_column1':'Salaries_for_Car'},inplace=True)

# %%
# the cities with the highest amount of salaries needed to buy a Toyota Corolla  1.6l 97kW Comfort (Or Equivalent New Car)
OECD.sort_values(by=['Salaries_for_Car','City'],ascending=False)
# Out:
#                                City  Salaries_to_buy_Apartment  \
# 61                 Bogota, Colombia                 467.021866
# 3                  Istanbul, Turkey                 151.632496
# 26                 Belgrade, Serbia                 306.205684
# 100              Bucharest, Romania                 157.546366
# 31                  Sofia, Bulgaria                 144.140194
# 85                 Lisbon, Portugal                 247.338743
# 81                   Athens, Greece                 248.581353
# 15              Mexico City, Mexico                 236.428353
# 91                Budapest, Hungary                 257.744130
# 55                  Santiago, Chile                 347.099251
# 36             Singapore, Singapore                 285.834194
# 70                   Warsaw, Poland                 229.157217
# 133                  Moscow, Russia                 255.367703
# 16                      Rome, Italy                 203.792307
# ...

# %%
# the cities with the highest amount of salaries needed to buy 100 sq meter Apartment outside the city center
OECD.sort_values(by=['Salaries_to_buy_Apartment','City'],ascending=False)
# Out:
#                                City  Salaries_to_buy_Apartment  \
# 83             Hong Kong, Hong Kong                 710.393106
# 114                  Taipei, Taiwan                 522.655751
# 61                 Bogota, Colombia                 467.021866
# 28                    Paris, France                 392.382911
# 55                  Santiago, Chile                 347.099251
# 113           Tel Aviv-Yafo, Israel                 323.812782
# 69               Seoul, South Korea                 307.588957
# 26                 Belgrade, Serbia                 306.205684
# 36             Singapore, Singapore                 285.834194
# 91                Budapest, Hungary                 257.744130
# 133                  Moscow, Russia                 255.367703
# 81                   Athens, Greece                 248.581353
# 85                 Lisbon, Portugal                 247.338743
# 15              Mexico City, Mexico                 236.428353
# ...

# %%
OECD.sort_values(by=['Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment','City'],ascending=False)
# Out:
#                                City  Salaries_to_buy_Apartment  \
# 33                  Berlin, Germany                 150.824951
# 113           Tel Aviv-Yafo, Israel                 323.812782
# 77              Copenhagen, Denmark                 137.756316
# 65           London, United Kingdom                 229.081060
# 40                     Tokyo, Japan                 223.333154
# 109                 Vienna, Austria                 206.356768
# 136             Zurich, Switzerland                 124.410751
# 25           Amsterdam, Netherlands                 169.733673
# 83             Hong Kong, Hong Kong                 710.393106
# 16                      Rome, Italy                 203.792307
# 28                    Paris, France                 392.382911
# 132                 Dublin, Ireland                 162.095625
# 68       Manchester, United Kingdom                 135.972214
# 70                   Warsaw, Poland                 229.157217
# ...

# %%
OECD.sort_values(by=['Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment','City'],ascending=True)
# Out:
#                                City  Salaries_to_buy_Apartment  \
# 15              Mexico City, Mexico                 236.428353
# 3                  Istanbul, Turkey                 151.632496
# 114                  Taipei, Taiwan                 522.655751
# 61                 Bogota, Colombia                 467.021866
# 125               Stockholm, Sweden                 217.241034
# 93       Johannesburg, South Africa                  58.383410
# 6                 Helsinki, Finland                 180.630373
# 100              Bucharest, Romania                 157.546366
# 36             Singapore, Singapore                 285.834194
# 31                  Sofia, Bulgaria                 144.140194
# 55                  Santiago, Chile                 347.099251
# 85                 Lisbon, Portugal                 247.338743
# 133                  Moscow, Russia                 255.367703
# 66   Los Angeles, CA, United States                 116.982054
# ...

# %%
OECD.sort_values(by=['Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate','City'],ascending=False)
# Out:
#                                City  Salaries_to_buy_Apartment  \
# 3                  Istanbul, Turkey                 151.632496
# 61                 Bogota, Colombia                 467.021866
# 15              Mexico City, Mexico                 236.428353
# 93       Johannesburg, South Africa                  58.383410
# 133                  Moscow, Russia                 255.367703
# 100              Bucharest, Romania                 157.546366
# 91                Budapest, Hungary                 257.744130
# 81                   Athens, Greece                 248.581353
# 70                   Warsaw, Poland                 229.157217
# 75      New York, NY, United States                 148.023588
# 66   Los Angeles, CA, United States                 116.982054
# 26                 Belgrade, Serbia                 306.205684
# 55                  Santiago, Chile                 347.099251
# 113           Tel Aviv-Yafo, Israel                 323.812782
# ...

# %%
OECD.to_csv("C:\\Users\\idoch\\OneDrive - Bar-Ilan University\\Documents\\Python Scripts\OECD.csv")

# %%
USA = df.copy()

# %%
USA= USA[(USA.City=='Austin, TX, United States')|
   (USA.City=='Dallas, TX, United States')|
   (USA.City=='Denver, CO, United States')|
   (USA.City=='Portland, OR, United States')|
   (USA.City=='Seattle, WA, United States')|
   (USA.City=='Chicago, IL, United States')|
   (USA.City=='Houston,TX,United States')|
   (USA.City=='New York,NY,United States')|
   (USA.City=='Miami,CA,United States')|
   (USA.City=='Los Angeles, CA, United States')|
   (USA.City=='San Francisco, CA, United States')|
   (USA.City=='San Diego, CA, United States')|
   (USA.City=='Boston, MA, United States').head()]

# %%
USA['new_column'] = "Salaries_for_Apartment"

# %%
USA['new_column'] = (100*df['Price per Square Meter to Buy Apartment Outside of Centre'])/(df['Average Monthly Net Salary (After Tax)'])

# %%
USA['City']= USA['City'].replace({'Austin, TX, United States':'Austin','Boston, MA, United States':'Boston','Chicago, IL, United States':'Chicago','Dallas, TX, United States':'Dallas','Denver, CO, United States':'Denver','Houston, TX, United States':'Houston','Las Vegas, NV, United States':'Las Vegas','Los Angeles, CA, United States':'Los Angeles','Miami, FL, United States':'Miami','Portland, OR, United States':'Portland','San Diego, CA, United States':'San Diego','San Francisco, CA, United States':'San Francisco','Seattle, WA, United States':'Seattle'})

# %%
USA= USA[['City','International Primary School, Yearly for 1 Child','new_column']]
USA.head(150)
# Out:
#              City  International Primary School, Yearly for 1 Child  \
# 35         Austin                                          16544.44
# 43        Chicago                                          18665.59
# 49         Dallas                                          16302.20
# 50         Denver                                          13961.29
# 66    Los Angeles                                          23178.05
# 84       Portland                                          18297.29
# 95      San Diego                                          21796.43
# 96  San Francisco                                          30183.68
# 99        Seattle                                          26836.36
#
#     new_column
# 35   47.742647
# 43   49.872096
# 49   33.656703
# 50   65.696330
# 66  116.982054
# 84   70.422442
# 95   78.898133
# 96  126.763160
# 99   81.188791

# %%
USA.rename(columns={'new_column':'Salaries_to_buy_Apartment'},inplace=True)

# %%
USA.sort_values(by=['Salaries_to_buy_Apartment','City'],ascending=False)
# Out:
#              City  International Primary School, Yearly for 1 Child  \
# 96  San Francisco                                          30183.68
# 66    Los Angeles                                          23178.05
# 99        Seattle                                          26836.36
# 95      San Diego                                          21796.43
# 84       Portland                                          18297.29
# 50         Denver                                          13961.29
# 43        Chicago                                          18665.59
# 35         Austin                                          16544.44
# 49         Dallas                                          16302.20
#
#     Salaries_to_buy_Apartment
# 96                 126.763160
# 66                 116.982054
# 99                  81.188791
# 95                  78.898133
# 84                  70.422442
# 50                  65.696330
# 43                  49.872096
# 35                  47.742647
# ...

# %%
USA.sort_values(by=['International Primary School, Yearly for 1 Child','City'],ascending=False)
# Out:
#              City  International Primary School, Yearly for 1 Child  \
# 96  San Francisco                                          30183.68
# 99        Seattle                                          26836.36
# 66    Los Angeles                                          23178.05
# 95      San Diego                                          21796.43
# 43        Chicago                                          18665.59
# 84       Portland                                          18297.29
# 35         Austin                                          16544.44
# 49         Dallas                                          16302.20
# 50         Denver                                          13961.29
#
#     Salaries_to_buy_Apartment
# 96                 126.763160
# 99                  81.188791
# 66                 116.982054
# 95                  78.898133
# 43                  49.872096
# 84                  70.422442
# 35                  47.742647
# 49                  33.656703
# ...

# %%
USA.to_csv("C:\\Users\\idoch\\OneDrive - Bar-Ilan University\\Documents\\Python Scripts\\USA.csv")

# %%
Europe = df.copy()

# %%
Europe= Europe[(Europe.City=='Moscow,Russia')|
   (Europe.City=='Brussels, Belgium')|
   (Europe.City=='Paris, France')|
   (Europe.City=='Zurich, Switzerland')|
   (Europe.City=='Stockholm, Sweden')|
   (Europe.City=='Rome, Italy')|
   (Europe.City=='Madrid, Spain')|
   (Europe.City=='Vienna, Austria')|
   (Europe.City=='Helsinki, Finland')|
   (Europe.City=='Amsterdam, Netherlands')|
   (Europe.City=='Stockholm,Sweden')|
   (Europe.City=='Oslo,Norway')|
   (Europe.City=='Sofia, Bulgaria')|
   (Europe.City=='Saint Petersburg, Russia')|
   (Europe.City=='Budapest, Hungary')|
   (Europe.City=='Copenhagen, Denmark')|
   (Europe.City=='Dublin, Ireland')|
   (Europe.City=='Istanbul, Turkey')|
   (Europe.City=='Athens,Greece')|
   (Europe.City=='Munich, Germany')|
   (Europe.City=='Berlin, Germany')|
   (Europe.City=='Belgrade, Serbia')|
   (Europe.City=='Prague, Czech Republic')|
   (Europe.City=='Lisbon, Portugal')|
   (Europe.City=='London, United Kingdom')|
   (Europe.City=='Manchester, United Kingdom').head()]

# %%
Europe['City']= Europe['City'].replace({'Istanbul, Turkey':'Istanbul','Zurich, Switzerland':'Zurich','Moscow, Russia':'Moscow','Dublin, Ireland':'Dublin','Minsk, Belarus':'Minsk','Stockholm, Sweden':'Stockholm','Skopje, North Macedonia':'Skopje','Vienna, Austria':'Vienna','Madrid, Spain':'Madrid','Barcelona, Spain':'Barcelona','Vilnius, Lithuania':'Vilnius','Budapest, Hungary':'Budapest','Lisbon, Portugal':'Lisbon','Athens, Greece':'Athens','Copenhagen, Denmark':'Copenhagen','Prague, Czech Republic':'Prague','Warsaw, Poland	':'Warsaw','Manchester, United Kingdom':'Manchester','London, United Kingdom':'London','Munich, Germany':'Munich','Hamburg, Germany':'Hamburg','Zagreb, Croatia':'Zagreb','Bratislava, Slovakia':'Bratislava','Berlin, Germany':'Berlin','Oslo, Norway':'Oslo','Sofia, Bulgaria':'Sofia','Paris, France':'Paris','Belgrade, Serbia':'Belgrade','Amsterdam, Netherlands':'Amsterdam','Kiev (Kyiv), Ukraine':'Kiev','Sarajevo, Bosnia And Herzegovina':'Sarajevo','Rome, Italy':'Rome','Helsinki, Finland':'Helsinki','Saint Petersburg, Russia':'St Petersburg','Brussels, Belgium':'Brussels','Sofia, Bulgaria':'Sofia'})

# %%
Europe['new_column'] = "Salaries_for_Apartment"

# %%
Europe.columns
# Out:
# Index(['Unnamed: 0', 'Rank', 'City', 'Meal, Inexpensive Restaurant',
#        'Meal for 2 People, Mid-range Restaurant, Three-course',
#        'McMeal at McDonalds (or Equivalent Combo Meal)',
#        'Domestic Beer (0.5 liter draught)',
#        'Imported Beer (0.33 liter bottle)', 'Coke/Pepsi (0.33 liter bottle)',
#        'Water (0.33 liter bottle)', 'Milk (regular), (1 liter)',
#        'Loaf of Fresh White Bread (500g)', 'Eggs (regular) (12)',
#        'Local Cheese (1kg)', 'Water (1.5 liter bottle)',
#        'Bottle of Wine (Mid-Range)', 'Domestic Beer (0.5 liter bottle)',
#        'Imported Beer (0.33 liter bottle).1', 'Cigarettes 20 Pack (Marlboro)',
#        'One-way Ticket (Local Transport)', 'Chicken Fillets (1kg)',
#        'Monthly Pass (Regular Price)', 'Gasoline (1 liter)',
#        'Volkswagen Golf 1.4 90 KW Trendline (Or Equivalent New Car)',
#        'Apartment (1 bedroom) in City Centre',
#        'Apartment (1 bedroom) Outside of Centre',
# ...

# %%
Europe['new_column'] = (100*df['Price per Square Meter to Buy Apartment Outside of Centre'])/(df['Average Monthly Net Salary (After Tax)'])

# %%
Europe =Europe[['City','Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment','Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child','Average Monthly Net Salary (After Tax)','new_column']]
Europe.head(150)
# Out:
#               City  \
# 0    St Petersburg
# 3         Istanbul
# 6         Helsinki
# 16            Rome
# 25       Amsterdam
# 26        Belgrade
# 28           Paris
# 31           Sofia
# 33          Berlin
# 62          Munich
# 65          London
# 71          Prague
# 77      Copenhagen
# 85          Lisbon
# 91        Budapest
# 102         Madrid
# 109         Vienna
# 125      Stockholm
# 132         Dublin
# 136         Zurich
# 146       Brussels
#
#      Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment  \
# 0                                               101.67
# 3                                                67.79
# 6                                                91.87
# 16                                              192.23
# 25                                              197.66
# 26                                              148.01
# 28                                              183.38
# ...

# %%
Europe.rename(columns={'new_column':'Salaries_to_buy_Apartment'},inplace=True)

# %%
Europe.sort_values(by=['Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child','City'],ascending=True)
# Out:
#               City  \
# 125      Stockholm
# 33          Berlin
# 109         Vienna
# 26        Belgrade
# 3         Istanbul
# 91        Budapest
# 6         Helsinki
# 31           Sofia
# 0    St Petersburg
# 85          Lisbon
# 77      Copenhagen
# 102         Madrid
# 16            Rome
# 71          Prague
# 62          Munich
# 146       Brussels
# 28           Paris
# 132         Dublin
# 65          London
# 25       Amsterdam
# 136         Zurich
#
#      Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment  \
# 125                                              80.84
# 33                                              255.12
# 109                                             201.70
# 26                                              148.01
# 3                                                67.79
# 91                                              163.88
# 6                                                91.87
# ...

# %%
Europe.sort_values(by=['Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child','City'],ascending=False)
# Out:
#               City  \
# 136         Zurich
# 25       Amsterdam
# 65          London
# 132         Dublin
# 28           Paris
# 146       Brussels
# 62          Munich
# 71          Prague
# 16            Rome
# 102         Madrid
# 77      Copenhagen
# 85          Lisbon
# 0    St Petersburg
# 31           Sofia
# 6         Helsinki
# 91        Budapest
# 3         Istanbul
# 26        Belgrade
# 109         Vienna
# 33          Berlin
# 125      Stockholm
#
#      Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment  \
# 136                                             198.52
# 25                                              197.66
# 65                                              211.60
# 132                                             169.53
# 28                                              183.38
# 146                                             152.44
# 62                                              275.61
# ...

# %%
Europe.sort_values(by=['Average Monthly Net Salary (After Tax)','City'],ascending=False)
# Out:
#               City  \
# 136         Zurich
# 65          London
# 77      Copenhagen
# 25       Amsterdam
# 62          Munich
# 6         Helsinki
# 33          Berlin
# 132         Dublin
# 125      Stockholm
# 146       Brussels
# 28           Paris
# 109         Vienna
# 102         Madrid
# 16            Rome
# 71          Prague
# 85          Lisbon
# 91        Budapest
# 31           Sofia
# 0    St Petersburg
# 26        Belgrade
# 3         Istanbul
#
#      Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment  \
# 136                                             198.52
# 65                                              211.60
# 77                                              215.51
# 25                                              197.66
# 62                                              275.61
# 6                                                91.87
# 33                                              255.12
# ...

# %%
Europe.sort_values(by=['Average Monthly Net Salary (After Tax)','City'],ascending=True)
# Out:
#               City  \
# 3         Istanbul
# 26        Belgrade
# 0    St Petersburg
# 31           Sofia
# 91        Budapest
# 85          Lisbon
# 71          Prague
# 16            Rome
# 102         Madrid
# 109         Vienna
# 28           Paris
# 146       Brussels
# 125      Stockholm
# 132         Dublin
# 33          Berlin
# 6         Helsinki
# 62          Munich
# 25       Amsterdam
# 77      Copenhagen
# 65          London
# 136         Zurich
#
#      Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment  \
# 3                                                67.79
# 26                                              148.01
# 0                                               101.67
# 31                                              112.40
# 91                                              163.88
# 85                                              118.56
# 71                                              186.35
# ...

# %%
Europe.sort_values(by=['Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment','City'],ascending=False)
# Out:
#               City  \
# 62          Munich
# 33          Berlin
# 77      Copenhagen
# 65          London
# 109         Vienna
# 136         Zurich
# 25       Amsterdam
# 16            Rome
# 71          Prague
# 28           Paris
# 132         Dublin
# 91        Budapest
# 146       Brussels
# 26        Belgrade
# 102         Madrid
# 85          Lisbon
# 31           Sofia
# 0    St Petersburg
# 6         Helsinki
# 125      Stockholm
# 3         Istanbul
#
#      Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment  \
# 62                                              275.61
# 33                                              255.12
# 77                                              215.51
# 65                                              211.60
# 109                                             201.70
# 136                                             198.52
# 25                                              197.66
# ...

# %%
Europe.sort_values(by=['Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment','City'],ascending=True)
# Out:
#               City  \
# 3         Istanbul
# 125      Stockholm
# 6         Helsinki
# 0    St Petersburg
# 31           Sofia
# 85          Lisbon
# 102         Madrid
# 26        Belgrade
# 146       Brussels
# 91        Budapest
# 132         Dublin
# 28           Paris
# 71          Prague
# 16            Rome
# 25       Amsterdam
# 136         Zurich
# 109         Vienna
# 65          London
# 77      Copenhagen
# 33          Berlin
# 62          Munich
#
#      Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment  \
# 3                                                67.79
# 125                                              80.84
# 6                                                91.87
# 0                                               101.67
# 31                                              112.40
# 85                                              118.56
# 102                                             145.25
# ...

# %%
Europe.sort_values(by=['Salaries_to_buy_Apartment','City'],ascending=False)
# Out:
#               City  \
# 28           Paris
# 26        Belgrade
# 71          Prague
# 62          Munich
# 91        Budapest
# 85          Lisbon
# 0    St Petersburg
# 65          London
# 125      Stockholm
# 109         Vienna
# 16            Rome
# 102         Madrid
# 6         Helsinki
# 25       Amsterdam
# 132         Dublin
# 3         Istanbul
# 33          Berlin
# 31           Sofia
# 77      Copenhagen
# 136         Zurich
# 146       Brussels
#
#      Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment  \
# 28                                              183.38
# 26                                              148.01
# 71                                              186.35
# 62                                              275.61
# 91                                              163.88
# 85                                              118.56
# 0                                               101.67
# ...

# %%
Europe.sort_values(by=['Salaries_to_buy_Apartment','City'],ascending=True)
# Out:
#               City  \
# 146       Brussels
# 136         Zurich
# 77      Copenhagen
# 31           Sofia
# 33          Berlin
# 3         Istanbul
# 132         Dublin
# 25       Amsterdam
# 6         Helsinki
# 102         Madrid
# 16            Rome
# 109         Vienna
# 125      Stockholm
# 65          London
# 0    St Petersburg
# 85          Lisbon
# 91        Budapest
# 62          Munich
# 71          Prague
# 26        Belgrade
# 28           Paris
#
#      Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment  \
# 146                                             152.44
# 136                                             198.52
# 77                                              215.51
# 31                                              112.40
# 33                                              255.12
# 3                                                67.79
# 132                                             169.53
# ...

# %%
Europe.to_csv("C:\\Users\\idoch\\OneDrive - Bar-Ilan University\\Documents\\Python Scripts\\Europe.csv")

# %%
df.dtypes

# %%
df.dtypes
